# %% [markdown]
# # Final project - Stephani Ceballos

# %% [markdown]
# **Description of the data**

# %% [markdown]
# In this dataset we can see the daily count of COVID 19 cases, hospitalizations and deaths in New York City. In the variables we can observe the day, death count, hospitalizations and cases, there is also a probable number of the same issues, this is because there may be cases that were not counted due to lack of information, etc. There are also variables in which we can observe the same theme but obtained weekly.

# %% [markdown]
# All variables are numeric, discrete, only the date is a string, ordinal.
#
# Important variables:
#
# * 'CASE_COUNT': display the daily count of covid 19 cases in New York City. Is a numeric variable, discreet.
# * 'HOSPITALIZED_COUNT':  display the daily count of hospitalization due to covid 19 in New York City. Is a numeric variable, discreet.
# * 'DEATH_COUNT': display the daily count of deaths due to covid 19 in New York City. Is a numeric variable, discreet.
# * 'DATE_OF_INTEREST': display the date in which the count was taken in New York City. Is a string variable, ordinal.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("datasets/COVID-19_Daily_Counts_of_Cases__Hospitalizations__and_Deaths.csv")
df.head(2)
# Out:
#   DATE_OF_INTEREST  CASE_COUNT  probable_case_count  HOSPITALIZED_COUNT  \
# 0       02/29/2020           1                    0                   1
# 1         03/01/20           0                    0                   1
#
#    DEATH_COUNT  DEATH_COUNT_PROBABLE  CASE_COUNT_7DAY_AVG  \
# 0            0                     0                    0
# 1            0                     0                    0
#
#    all_case_count_7day_avg  HOSP_COUNT_7DAY_AVG  DEATH_COUNT_7DAY_AVG  ...  \
# 0                        0                    0                     0  ...
# 1                        0                    0                     0  ...
#
#    si_probable_case_count  SI_HOSPITALIZED_COUNT  SI_DEATH_COUNT  \
# 0                       0                      0               0
# 1                       0                      0               0
#
#    si_probable_death_count  SI_CASE_COUNT_7DAY_AVG  \
# 0                        0                       0
# 1                        0                       0
#
#    si_all_case_count_7day_avg  SI_HOSPITALIZED_COUNT_7DAY_AVG  \
# 0                           0                               0
# 1                           0                               0
#
#    SI_DEATH_COUNT_7DAY_AVG  si_all_death_count_7day_avg  INCOMPLETE
# 0                        0                            0           0
# 1                        0                            0           0
#
# [2 rows x 62 columns]

# %% [markdown]
# **Interesting observations**

# %% [markdown]
# * There was a huge wave of this pandemic situation in which, New York City reach more than 50,000 positive cases of Covid-19 per day.

# %%
df.loc[:, 'CASE_COUNT'].max()
# Out:
# 54767

# %%
* The hugest wave of cases

# %%
df.describe()
# Out:
#          CASE_COUNT  probable_case_count  HOSPITALIZED_COUNT  DEATH_COUNT  \
# count    731.000000           731.000000          731.000000   731.000000
# mean    2652.082079           465.993160          201.128591    46.898769
# std     6033.148680           748.807122          294.289132    90.812335
# min        0.000000             0.000000            1.000000     0.000000
# 25%      412.500000            42.000000           42.000000     7.000000
# 50%     1057.000000           227.000000           84.000000    14.000000
# 75%     2790.000000           603.500000          261.500000    52.000000
# max    54767.000000          5889.000000         1850.000000   598.000000
#
#        DEATH_COUNT_PROBABLE  CASE_COUNT_7DAY_AVG  all_case_count_7day_avg  \
# count            731.000000           731.000000               731.000000
# mean               7.545828          2650.073871              3115.744186
# std               27.734337          5548.073748              6207.994833
# min                0.000000             0.000000                 0.000000
# 25%                0.000000           427.000000               503.500000
# 50%                1.000000          1119.000000              1447.000000
# 75%                3.000000          2844.500000              3615.500000
# max              227.000000         39248.000000             43736.000000
#
#        HOSP_COUNT_7DAY_AVG  DEATH_COUNT_7DAY_AVG  all_death_count_7day_avg  \
# count           731.000000            731.000000                731.000000
# mean            201.079343             46.846785                 54.398085
# std             289.115878             89.739294                115.934944
# min               0.000000              0.000000                  0.000000
# 25%              42.000000              7.000000                  8.000000
# 50%              87.000000             13.000000                 14.000000
# 75%             269.500000             52.000000                 54.000000
# max            1669.000000            566.000000                762.000000
#
#        ...  si_probable_case_count  SI_HOSPITALIZED_COUNT  SI_DEATH_COUNT  \
# count  ...              731.000000             731.000000      731.000000
# mean   ...               30.518468              11.625171        2.804378
# std    ...               41.445103              13.784511        4.477191
# min    ...                0.000000               0.000000        0.000000
# 25%    ...                2.000000               3.000000        0.000000
# 50%    ...               16.000000               6.000000        1.000000
# 75%    ...               47.000000              16.500000        4.000000
# max    ...              317.000000              83.000000       34.000000
#
#        si_probable_death_count  SI_CASE_COUNT_7DAY_AVG  \
# count               731.000000              731.000000
# mean                  0.318741              193.930233
# std                   1.137609              362.341448
# min                   0.000000                0.000000
# 25%                   0.000000               30.000000
# 50%                   0.000000               93.000000
# 75%                   0.000000              219.000000
# max                   9.000000             2667.000000
#
#        si_all_case_count_7day_avg  SI_HOSPITALIZED_COUNT_7DAY_AVG  \
# count                  731.000000                      731.000000
# mean                   224.462380                       11.616963
# std                    396.652769                       13.254555
# min                      0.000000                        0.000000
# 25%                     34.500000                        3.000000
# 50%                    112.000000                        6.000000
# 75%                    272.000000                       17.000000
# max                   2886.000000                       72.000000
#
#        SI_DEATH_COUNT_7DAY_AVG  si_all_death_count_7day_avg    INCOMPLETE
# count               731.000000                   731.000000    731.000000
# mean                  2.777018                     3.097127    581.833105
# std                   4.185208                     5.114859   5921.284795
# min                   0.000000                     0.000000      0.000000
# 25%                   0.000000                     1.000000      0.000000
# 50%                   1.000000                     1.000000      0.000000
# 75%                   4.000000                     4.000000      0.000000
# max                  26.000000                    33.000000  60760.000000
#
# [8 rows x 61 columns]

# %%
pd.pivot_table(df,
 index = ['DATE_OF_INTEREST'],
 aggfunc = ['median', 'mean'],
 values = ['CASE_COUNT','HOSPITALIZED_COUNT','DEATH_COUNT'],
 margins = True,
 )
# Out:
#                      median                                         mean  \
#                  CASE_COUNT DEATH_COUNT HOSPITALIZED_COUNT    CASE_COUNT
# DATE_OF_INTEREST
# 01/01/21               1340          36                301   1340.000000
# 01/01/22              12002          56                859  12002.000000
# 01/02/21               4202          57                326   4202.000000
# 01/02/22              32377          62               1295  32377.000000
# 01/03/21               3465          38                302   3465.000000
# ...                     ...         ...                ...           ...
# 12/30/2020             4985          40                316   4985.000000
# 12/30/2021            47056          35               1022  47056.000000
# 12/31/2020             3393          41                284   3393.000000
# 12/31/2021            29002          54                816  29002.000000
# All                    1057          14                 84   2652.082079
#
#
#                  DEATH_COUNT HOSPITALIZED_COUNT
# DATE_OF_INTEREST
# 01/01/21           36.000000         301.000000
# 01/01/22           56.000000         859.000000
# 01/02/21           57.000000         326.000000
# 01/02/22           62.000000        1295.000000
# 01/03/21           38.000000         302.000000
# ...                      ...                ...
# 12/30/2020         40.000000         316.000000
# 12/30/2021         35.000000        1022.000000
# 12/31/2020         41.000000         284.000000
# 12/31/2021         54.000000         816.000000
# All                46.898769         201.128591
#
# [732 rows x 6 columns]

# %%
df[['CASE_COUNT','DEATH_COUNT','HOSPITALIZED_COUNT']].describe()
# Out:
#          CASE_COUNT  DEATH_COUNT  HOSPITALIZED_COUNT
# count    731.000000   731.000000          731.000000
# mean    2652.082079    46.898769          201.128591
# std     6033.148680    90.812335          294.289132
# min        0.000000     0.000000            1.000000
# 25%      412.500000     7.000000           42.000000
# 50%     1057.000000    14.000000           84.000000
# 75%     2790.000000    52.000000          261.500000
# max    54767.000000   598.000000         1850.000000

# %%
df.transpose()
# Out:
#                                        0         1         2         3    \
# DATE_OF_INTEREST                02/29/2020  03/01/20  03/02/20  03/03/20
# CASE_COUNT                               1         0         0         1
# probable_case_count                      0         0         0         0
# HOSPITALIZED_COUNT                       1         1         2         7
# DEATH_COUNT                              0         0         0         0
# ...                                    ...       ...       ...       ...
# si_all_case_count_7day_avg               0         0         0         0
# SI_HOSPITALIZED_COUNT_7DAY_AVG           0         0         0         0
# SI_DEATH_COUNT_7DAY_AVG                  0         0         0         0
# si_all_death_count_7day_avg              0         0         0         0
# INCOMPLETE                               0         0         0         0
#
#                                      4         5         6         7    \
# DATE_OF_INTEREST                03/04/20  03/05/20  03/06/20  03/07/20
# CASE_COUNT                             5         3         8         7
# probable_case_count                    0         0         0         0
# HOSPITALIZED_COUNT                     2        14         8         8
# DEATH_COUNT                            0         0         0         0
# ...                                  ...       ...       ...       ...
# si_all_case_count_7day_avg             0         0         0         0
# SI_HOSPITALIZED_COUNT_7DAY_AVG         0         0         0         0
# SI_DEATH_COUNT_7DAY_AVG                0         0         0         0
# si_all_death_count_7day_avg            0         0         0         0
# INCOMPLETE                             0         0         0         0
#
#                                      8         9    ...         721  \
# DATE_OF_INTEREST                03/08/20  03/09/20  ...  02/19/2022
# CASE_COUNT                            21        57  ...         423
# probable_case_count                    0         0  ...          70
# HOSPITALIZED_COUNT                    18        37  ...          44
# DEATH_COUNT                            0         0  ...          28
# ...                                  ...       ...  ...         ...
# si_all_case_count_7day_avg             0         1  ...          59
# SI_HOSPITALIZED_COUNT_7DAY_AVG         0         1  ...           5
# SI_DEATH_COUNT_7DAY_AVG                0         0  ...           2
# si_all_death_count_7day_avg            0         0  ...           2
# INCOMPLETE                             0         0  ...           0
#
#                                        722         723         724  \
# DATE_OF_INTEREST                02/20/2022  02/21/2022  02/22/2022
# CASE_COUNT                             378         541         671
# probable_case_count                     57          90          91
# HOSPITALIZED_COUNT                      32          40          45
# DEATH_COUNT                             15          25          12
# ...                                    ...         ...         ...
# si_all_case_count_7day_avg              58          53          50
# SI_HOSPITALIZED_COUNT_7DAY_AVG           4           4           4
# SI_DEATH_COUNT_7DAY_AVG                  2           2           1
# si_all_death_count_7day_avg              2           2           1
# INCOMPLETE                               0           0       60760
#
#                                        725         726         727  \
# DATE_OF_INTEREST                02/23/2022  02/24/2022  02/25/2022
# CASE_COUNT                             687         638         499
# probable_case_count                     69          83          36
# HOSPITALIZED_COUNT                      35          31          25
# DEATH_COUNT                             16          15          11
# ...                                    ...         ...         ...
# si_all_case_count_7day_avg              47          46          43
# SI_HOSPITALIZED_COUNT_7DAY_AVG           3           3           3
# SI_DEATH_COUNT_7DAY_AVG                  1           1           1
# si_all_death_count_7day_avg              1           2           1
# INCOMPLETE                           60760       60760       60760
#
#                                        728         729         730
# DATE_OF_INTEREST                02/26/2022  02/27/2022  02/28/2022
# CASE_COUNT                             321         346         627
# probable_case_count                     81          69          95
# HOSPITALIZED_COUNT                       3           4           1
# DEATH_COUNT                              5          11           3
# ...                                    ...         ...         ...
# si_all_case_count_7day_avg              41          40          41
# SI_HOSPITALIZED_COUNT_7DAY_AVG           3           2           2
# SI_DEATH_COUNT_7DAY_AVG                  1           1           1
# si_all_death_count_7day_avg              1           1           1
# INCOMPLETE                           60760       60760       60760
#
# [62 rows x 731 columns]

# %%
df.columns
# Out:
# Index(['DATE_OF_INTEREST', 'CASE_COUNT', 'probable_case_count',
#        'HOSPITALIZED_COUNT', 'DEATH_COUNT', 'DEATH_COUNT_PROBABLE',
#        'CASE_COUNT_7DAY_AVG', 'all_case_count_7day_avg', 'HOSP_COUNT_7DAY_AVG',
#        'DEATH_COUNT_7DAY_AVG', 'all_death_count_7day_avg', 'BX_CASE_COUNT',
#        'bx_probable_case_count', 'BX_HOSPITALIZED_COUNT', 'BX_DEATH_COUNT',
#        'bx_probable_death_count', 'BX_CASE_COUNT_7DAY_AVG',
#        'bx_all_case_count_7day_avg', 'BX_HOSPITALIZED_COUNT_7DAY_AVG',
#        'BX_DEATH_COUNT_7DAY_AVG', 'bx_all_death_count_7day_avg',
#        'BK_CASE_COUNT', 'bk_probable_case_count', 'BK_HOSPITALIZED_COUNT',
#        'BK_DEATH_COUNT', 'bk_probable_death_count', 'BK_CASE_COUNT_7DAY_AVG',
#        'bk_all_case_count_7day_avg', 'BK_HOSPITALIZED_COUNT_7DAY_AVG',
#        'BK_DEATH_COUNT_7DAY_AVG', 'bk_all_death_count_7day_avg',
#        'MN_CASE_COUNT', 'mn_probable_case_count', 'MN_HOSPITALIZED_COUNT',
#        'MN_DEATH_COUNT', 'mn_probable_death_count', 'MN_CASE_COUNT_7DAY_AVG',
#        'mn_all_case_count_7day_avg', 'MN_HOSPITALIZED_COUNT_7DAY_AVG',
#        'MN_DEATH_COUNT_7DAY_AVG', 'mn_all_death_count_7day_avg',
#        'QN_CASE_COUNT', 'qn_probable_case_count', 'QN_HOSPITALIZED_COUNT',
#        'QN_DEATH_COUNT', 'qn_probable_death_count', 'QN_CASE_COUNT_7DAY_AVG',
#        'qn_all_case_count_7day_avg', 'QN_HOSPITALIZED_COUNT_7DAY_AVG',
#        'QN_DEATH_COUNT_7DAY_AVG', 'qn_all_death_count_7day_avg',
#        'SI_CASE_COUNT', 'si_probable_case_count', 'SI_HOSPITALIZED_COUNT',
#        'SI_DEATH_COUNT', 'si_probable_death_count', 'SI_CASE_COUNT_7DAY_AVG',
#        'si_all_case_count_7day_avg', 'SI_HOSPITALIZED_COUNT_7DAY_AVG',
#        'SI_DEATH_COUNT_7DAY_AVG', 'si_all_death_count_7day_avg', 'INCOMPLETE'],
#       dtype='object')

# %%
df.drop(['probable_case_count','CASE_COUNT_7DAY_AVG', 'all_case_count_7day_avg', 'HOSP_COUNT_7DAY_AVG',
       'DEATH_COUNT_7DAY_AVG', 'all_death_count_7day_avg', 'BX_CASE_COUNT',
       'bx_probable_case_count', 'BX_HOSPITALIZED_COUNT', 'BX_DEATH_COUNT',
       'bx_probable_death_count', 'BX_CASE_COUNT_7DAY_AVG',
       'bx_all_case_count_7day_avg', 'BX_HOSPITALIZED_COUNT_7DAY_AVG',
       'BX_DEATH_COUNT_7DAY_AVG', 'bx_all_death_count_7day_avg',
       'BK_CASE_COUNT', 'bk_probable_case_count', 'BK_HOSPITALIZED_COUNT',
       'BK_DEATH_COUNT', 'bk_probable_death_count', 'BK_CASE_COUNT_7DAY_AVG',
       'bk_all_case_count_7day_avg', 'BK_HOSPITALIZED_COUNT_7DAY_AVG',
       'BK_DEATH_COUNT_7DAY_AVG', 'bk_all_death_count_7day_avg',
       'MN_CASE_COUNT', 'mn_probable_case_count', 'MN_HOSPITALIZED_COUNT',
       'MN_DEATH_COUNT', 'mn_probable_death_count', 'MN_CASE_COUNT_7DAY_AVG',
       'mn_all_case_count_7day_avg', 'MN_HOSPITALIZED_COUNT_7DAY_AVG',
       'MN_DEATH_COUNT_7DAY_AVG', 'mn_all_death_count_7day_avg',
       'QN_CASE_COUNT', 'qn_probable_case_count', 'QN_HOSPITALIZED_COUNT',
       'QN_DEATH_COUNT', 'qn_probable_death_count', 'QN_CASE_COUNT_7DAY_AVG',
       'qn_all_case_count_7day_avg', 'QN_HOSPITALIZED_COUNT_7DAY_AVG',
       'QN_DEATH_COUNT_7DAY_AVG', 'qn_all_death_count_7day_avg',
       'SI_CASE_COUNT', 'si_probable_case_count', 'SI_HOSPITALIZED_COUNT',
       'SI_DEATH_COUNT', 'si_probable_death_count', 'SI_CASE_COUNT_7DAY_AVG',
       'si_all_case_count_7day_avg', 'SI_HOSPITALIZED_COUNT_7DAY_AVG',
       'SI_DEATH_COUNT_7DAY_AVG', 'si_all_death_count_7day_avg', 'INCOMPLETE','DEATH_COUNT_PROBABLE',],
        axis = 1,
        inplace = True
       )

# %%
df.head(2)
# Out:
#   DATE_OF_INTEREST  CASE_COUNT  HOSPITALIZED_COUNT  DEATH_COUNT
# 0       02/29/2020           1                   1            0
# 1         03/01/20           0                   1            0

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.style.use('classic')

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
#c19 = df.sort_values(['DATE_OF_INTEREST'], ascending = False, axis = 0)

# %%
pd.pivot_table(df,
 index = ['DATE_OF_INTEREST'],
 aggfunc = ['median', 'mean'],
 values = ['CASE_COUNT','HOSPITALIZED_COUNT','DEATH_COUNT'],
 margins = True
 )
# Out:
#                      median                                         mean  \
#                  CASE_COUNT DEATH_COUNT HOSPITALIZED_COUNT    CASE_COUNT
# DATE_OF_INTEREST
# 01/01/21               1340          36                301   1340.000000
# 01/01/22              12002          56                859  12002.000000
# 01/02/21               4202          57                326   4202.000000
# 01/02/22              32377          62               1295  32377.000000
# 01/03/21               3465          38                302   3465.000000
# ...                     ...         ...                ...           ...
# 12/30/2020             4985          40                316   4985.000000
# 12/30/2021            47056          35               1022  47056.000000
# 12/31/2020             3393          41                284   3393.000000
# 12/31/2021            29002          54                816  29002.000000
# All                    1057          14                 84   2652.082079
#
#
#                  DEATH_COUNT HOSPITALIZED_COUNT
# DATE_OF_INTEREST
# 01/01/21           36.000000         301.000000
# 01/01/22           56.000000         859.000000
# 01/02/21           57.000000         326.000000
# 01/02/22           62.000000        1295.000000
# 01/03/21           38.000000         302.000000
# ...                      ...                ...
# 12/30/2020         40.000000         316.000000
# 12/30/2021         35.000000        1022.000000
# 12/31/2020         41.000000         284.000000
# 12/31/2021         54.000000         816.000000
# All                46.898769         201.128591
#
# [732 rows x 6 columns]

# %%
#c19 = df.transpose()

# %%
df.plot(figsize = (20,10))
plt.xlabel('Index', fontsize = 17)
plt.xticks(fontsize = 17, rotation = 45)
plt.ylabel('Cases', fontsize = 17)
plt.yticks(fontsize = 17)
plt.title('New York City', fontsize = 17)
# Out:
# Text(0.5, 1.0, 'New York City')

# %%
df
# Out:
#     DATE_OF_INTEREST  CASE_COUNT  HOSPITALIZED_COUNT  DEATH_COUNT
# 0         02/29/2020           1                   1            0
# 1           03/01/20           0                   1            0
# 2           03/02/20           0                   2            0
# 3           03/03/20           1                   7            0
# 4           03/04/20           5                   2            0
# ..               ...         ...                 ...          ...
# 726       02/24/2022         638                  31           15
# 727       02/25/2022         499                  25           11
# 728       02/26/2022         321                   3            5
# 729       02/27/2022         346                   4           11
# 730       02/28/2022         627                   1            3
#
# [731 rows x 4 columns]

# %%
df.loc[:, 'HOSPITALIZED_COUNT'].max()
# Out:
# 1850

# %%
df.loc[:, 'DEATH_COUNT'].max()
# Out:
# 598

# %%
df.columns = list(map(str, df.columns))
df.columns
#df.loc([:, 'DEATH_COUNT'],:'630').plot
# Out:
# Index(['DATE_OF_INTEREST', 'CASE_COUNT', 'HOSPITALIZED_COUNT', 'DEATH_COUNT'], dtype='object')

# %%
df.set_index('DATE_OF_INTEREST', inplace = True)
df.head()
# Out:
#                   CASE_COUNT  HOSPITALIZED_COUNT  DEATH_COUNT
# DATE_OF_INTEREST
# 02/29/2020                 1                   1            0
# 03/01/20                   0                   1            0
# 03/02/20                   0                   2            0
# 03/03/20                   1                   7            0
# 03/04/20                   5                   2            0

# %%
df.iloc[:,2]
# Out:
# DATE_OF_INTEREST
# 02/29/2020     0
# 03/01/20       0
# 03/02/20       0
# 03/03/20       0
# 03/04/20       0
#               ..
# 02/24/2022    15
# 02/25/2022    11
# 02/26/2022     5
# 02/27/2022    11
# 02/28/2022     3
# Name: DEATH_COUNT, Length: 731, dtype: int64

# %%
#df.transpose()

# %%
df.columns
# Out:
# Index(['CASE_COUNT', 'HOSPITALIZED_COUNT', 'DEATH_COUNT'], dtype='object')

# %%
#df.columns = list(map(str, df.columns))
df.columns
# Out:
# Index(['CASE_COUNT', 'HOSPITALIZED_COUNT', 'DEATH_COUNT'], dtype='object')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.style.use('Solarize_Light2')
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
mar_data = df.iloc[14:52,1:]
mar_data.plot(figsize = (20,10))
plt.xlabel('Date', fontsize = 17)
plt.xticks(fontsize = 17, rotation = 45)
plt.ylabel('Cases', fontsize = 17)
plt.yticks(fontsize = 17)
plt.title('March data', fontsize = 17)
# Out:
# Text(0.5, 1.0, 'March data')
