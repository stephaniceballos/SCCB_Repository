# %%
import pandas as pd
import numpy as np
# %ls datasets
# Out:
# adult.csv                    census.csv     nhanes_2015_2016.csv
# airline_data.csv             coches.csv     pokemon.csv
# antropometria00.csv          cwurData.csv   reg_data.csv
# antropometria-dataset-2.csv  data.csv       sample_pivot.csv
# antropometria-dataset.csv    headbrain.csv  tips.csv
# Book3.csv                    mic2.xlsx      weight-height.csv
# Canada.xlsx                  mic.xlsx
# Cartwheeldata.csv            movies.csv

# %%
df = pd.read_csv('datasets/antropometria-dataset-2.csv')

# %%
df.head(5)
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 4  210939     3       21            PUEBLA     2    19      3  97.95     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
# 4  161.0  ...     6:00      2      6:00            1     M2123        5
#
#   est_urb est_marg       pondef  est_var
# ...

# %%
pd.pivot_table(df,
               index = ['desc_ent'],
               values = 'peso',
               columns = 'sexo',
               margins = True
              )
# Out:
# sexo                                     1          2        All
# desc_ent
# AGUASCALIENTES                   69.985381  63.254292  66.357786
# BAJA CALIFORNIA                  71.391818  65.893667  68.467270
# BAJA CALIFORNIA SUR              75.561015  68.168959  71.809198
# CAMPECHE                         68.622637  62.920493  65.418475
# CHIAPAS                          58.365222  57.096111  57.613775
# CHIHUAHUA                        68.892642  64.815295  66.656005
# COAHUILA DE ZARAGOZA             68.873094  67.467348  68.154142
# COLIMA                           70.998878  66.978393  68.743648
# DISTRITO FEDERAL                 69.460661  61.654128  65.119273
# DURANGO                          68.846451  64.400031  66.354922
# GUANAJUATO                       65.008000  63.100995  63.936390
# GUERRERO                         62.611437  58.899850  60.466315
# HIDALGO                          61.747958  58.972554  59.995917
# ...

# %%
pd.pivot_table(df,
               index = ['desc_ent'],
               values = 'peso',
               columns = 'sexo',
               aggfunc = ['median'],
               margins = True
              )
# Out:
#                                   median
# sexo                                   1        2      All
# desc_ent
# AGUASCALIENTES                   69.9500  63.7000  66.6000
# BAJA CALIFORNIA                  70.6500  64.2000  67.9500
# BAJA CALIFORNIA SUR              76.6500  68.5500  71.2500
# CAMPECHE                         67.3500  62.3750  64.3500
# CHIAPAS                          59.2000  56.0250  57.2000
# CHIHUAHUA                        69.3000  64.6250  66.3000
# COAHUILA DE ZARAGOZA             68.3000  67.3000  67.7000
# COLIMA                           71.7000  66.0000  68.9000
# DISTRITO FEDERAL                 69.0000  61.4500  64.0250
# DURANGO                          70.3500  62.5000  65.7000
# GUANAJUATO                       65.0625  60.3250  62.0625
# GUERRERO                         60.5000  57.2000  57.9500
# HIDALGO                          63.3000  57.9000  59.7000
# JALISCO                          65.5875  63.3500  64.2000
# ...

# %%
df.groupby(['sexo', 'peso']).size()
# Out:
# sexo  peso
# 1     20.550     1
#       22.750     1
#       22.825     1
#       23.000     1
#       23.075     1
#                 ..
# 2     151.550    1
#       154.100    1
#       161.450    1
#       165.000    1
#       168.600    1
# Length: 4207, dtype: int64

# %%
df['peso'].describe()
# Out:
# count    18640.000000
# mean        64.638707
# std         17.660325
# min         18.000000
# 25%         52.700000
# 50%         63.700000
# 75%         75.400000
# max        170.600000
# Name: peso, dtype: float64

# %%
pd.pivot_table(df,
               index = ['desc_ent'],
               aggfunc = ['mean'],
               values = ['peso'],
               columns = 'sexo',
               margins = True
              )
# Out:
#                                       mean
#                                       peso
# sexo                                     1          2        All
# desc_ent
# AGUASCALIENTES                   69.985381  63.254292  66.357786
# BAJA CALIFORNIA                  71.391818  65.893667  68.467270
# BAJA CALIFORNIA SUR              75.561015  68.168959  71.809198
# CAMPECHE                         68.622637  62.920493  65.418475
# CHIAPAS                          58.365222  57.096111  57.613775
# CHIHUAHUA                        68.892642  64.815295  66.656005
# COAHUILA DE ZARAGOZA             68.873094  67.467348  68.154142
# COLIMA                           70.998878  66.978393  68.743648
# DISTRITO FEDERAL                 69.460661  61.654128  65.119273
# DURANGO                          68.846451  64.400031  66.354922
# GUANAJUATO                       65.008000  63.100995  63.936390
# GUERRERO                         62.611437  58.899850  60.466315
# ...

# %%
df = pd.read_csv("datasets/adult.csv")
df.head(2)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         marital-status        occupation    relationship    race    sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country the label
# 0          2174             0              40   United-States     <=50K
# 1             0             0              13   United-States     <=50K

# %%
pd.pivot_table(df,
               index = ['marital-status'],
               aggfunc = ['mean'],
               values = ['hours-per-week'],
               columns = ['education'],
               margins = True
              )
# Out:
#                                  mean                                   \
#                        hours-per-week
# education                        10th       11th       12th    1st-4th
# marital-status
#  Divorced                   40.808333  40.023077  39.692308  32.800000
#  Married-AF-spouse                NaN        NaN        NaN        NaN
#  Married-civ-spouse         41.664756  40.514124  42.561538  39.802469
#  Married-spouse-absent      41.866667  39.526316  42.625000  39.916667
#  Never-married              31.168975  28.047782  30.702586  39.307692
#  Separated                  40.489796  38.416667  39.214286  38.888889
#  Widowed                    32.512821  33.868421  39.900000  30.176471
#  test_category_female             NaN        NaN        NaN        NaN
#  test_category_male               NaN        NaN        NaN        NaN
# All                         37.052519  33.925957  35.780600  38.255952
#
# ...

# %%
pd.pivot_table(df,
               index = ['marital-status','education'],
               aggfunc = ['median'],
               values = ['age'],
               columns = ['sex'],
               margins = True
              ).head(45)
# Out:
#                                       median
#                                          age
# sex                                   Female  Male   All
# marital-status         education
#  Divorced               10th            45.0  39.0  40.5
#                         11th            41.0  38.0  39.0
#                         12th            41.0  41.0  41.0
#                         1st-4th         64.0  63.0  63.5
#                         5th-6th         53.0  56.0  56.0
#                         7th-8th         52.0  49.5  51.0
#                         9th             46.0  46.0  46.0
#                         Assoc-acdm      40.0  41.0  40.0
#                         Assoc-voc       41.0  38.0  40.0
#                         Bachelors       43.0  44.0  43.0
#                         Doctorate       50.5  50.0  50.0
#                         HS-grad         43.0  40.0  41.0
#                         Masters         46.0  47.0  46.0
# ...
