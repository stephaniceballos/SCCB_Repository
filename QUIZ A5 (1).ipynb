# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("datasets/antropometria-dataset.csv")
df.head(2)
# Out:
#     folio  intp  entidad desc_ent  sexo  edad  meses   peso  ropa  talla  ...  \
# 0  210295     2       21   PUEBLA     2    38      8  73.70     2  146.4  ...
# 1  101655     3       10  DURANGO     2    11     11  35.65     2  145.1  ...
#
#   hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis est_urb est_marg  \
# 0    16:30      2     16:35            1     R2101        5       3        1
# 1    15:25      3     15:25            1     M1041        1       1        1
#
#         pondef  est_var
# 0  3470.002176      215
# 1   417.946672      101
#
# [2 rows x 26 columns]

# %%
# %ls datasets
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       reg_data.csv
# Book3.csv                  headbrain.csv  sample_pivot.csv
# Canada.xlsx                mic2.xlsx      tips.csv
# Cartwheeldata.csv          mic.xlsx       weight-height.csv

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
data =  pd.pivot_table(df,
 index = ['desc_ent'],
 aggfunc = ['median'],
 values = ['cintura'],
columns = 'sexo',
 )
data
# Out:
#                                  median
#                                 cintura
# sexo                                  1       2
# desc_ent
# AGUASCALIENTES                   89.425  88.150
# BAJA CALIFORNIA                  89.800  88.250
# BAJA CALIFORNIA SUR              92.500  90.000
# CAMPECHE                         91.000  87.225
# CHIAPAS                          79.925  83.225
# CHIHUAHUA                        88.500  88.000
# COAHUILA DE ZARAGOZA             89.000  90.800
# COLIMA                           91.300  90.250
# DISTRITO FEDERAL                 90.350  86.600
# DURANGO                          89.600  87.600
# GUANAJUATO                       85.500  89.000
# GUERRERO                         81.750  87.100
# HIDALGO                          83.950  85.000
# JALISCO                          87.275  89.175
# MEXICO                           83.900  83.950
# MICHOACAN DE OCAMPO              87.800  89.050
# MORELOS                          88.450  88.000
# NAYARIT                          87.150  86.050
# NUEVO LEON                       91.000  88.550
# OAXACA                           81.600  85.350
# PUEBLA                           84.075  85.575
# QUERETARO                        86.450  86.050
# QUINTANA ROO                     87.425  87.500
# SAN LUIS POTOSI                  83.850  85.225
# SINALOA                          89.500  87.250
# SONORA                           90.500  87.800
# TABASCO                          88.100  86.450
# TAMAULIPAS                       91.900  90.000
# TLAXCALA                         86.325  85.900
# VERACRUZ DE IGNACIO DE LA LLAVE  85.475  87.125
# YUCATAN                          87.000  88.050
# ZACATECAS                        87.200  86.500

# %%
data.plot()

# %%
data =  pd.pivot_table(df,
 index = ['desc_ent'],
 aggfunc = ['median'],
 values = ['ropa'],
columns = 'sexo',
 )
data
# Out:
#                                 median
#                                   ropa
# sexo                                 1    2
# desc_ent
# AGUASCALIENTES                     2.0  2.0
# BAJA CALIFORNIA                    2.0  2.0
# BAJA CALIFORNIA SUR                2.0  2.0
# CAMPECHE                           1.0  1.0
# CHIAPAS                            2.0  1.5
# CHIHUAHUA                          2.0  2.0
# COAHUILA DE ZARAGOZA               1.0  1.0
# COLIMA                             2.0  2.0
# DISTRITO FEDERAL                   1.0  1.0
# DURANGO                            2.0  2.0
# GUANAJUATO                         2.0  2.0
# GUERRERO                           2.0  2.0
# HIDALGO                            2.0  2.0
# JALISCO                            2.0  2.0
# MEXICO                             1.0  1.0
# MICHOACAN DE OCAMPO                2.0  2.0
# MORELOS                            2.0  2.0
# NAYARIT                            2.0  2.0
# NUEVO LEON                         1.0  1.0
# OAXACA                             2.0  2.0
# PUEBLA                             2.0  2.0
# QUERETARO                          2.0  2.0
# QUINTANA ROO                       2.0  2.0
# SAN LUIS POTOSI                    2.0  2.0
# SINALOA                            2.0  2.0
# SONORA                             2.0  2.0
# TABASCO                            1.0  1.0
# TAMAULIPAS                         1.0  1.0
# TLAXCALA                           2.0  2.0
# VERACRUZ DE IGNACIO DE LA LLAVE    2.0  2.0
# YUCATAN                            2.0  2.0
# ZACATECAS                          2.0  1.0

# %%
x = list(pd['ropa'])
y = list(pd['desc_ent'])
bins = 25
plt.subplot(1,2,1)
plt.rcParams['figure.figsize'] = (15,7)
plt.bar(x, y, width = 0.7, color = 'pink')
plt.xlabel('Age Group', fontweight = 'regular', color = 'purple', fontsize = 14,
          horizontalalignment = 'center')
plt.xlabel('Age', fontweight = 'regular', color = 'skyblue', fontsize = 14,
          horizontalalignment = 'center')
plt.xticks(fontsize = 17)
plt.yticks(fontsize = 17)
plt.title('Number of respondents of different age groups', y = 1.01)

# %%
data =  pd.pivot_table(df,
 index = ['desc_ent'],
 aggfunc = ['sum'],
 values = ['cadera'],
 )
data
# Out:
#                                       sum
#                                    cadera
# desc_ent
# AGUASCALIENTES                   61983.75
# BAJA CALIFORNIA                  54406.66
# BAJA CALIFORNIA SUR              51863.51
# CAMPECHE                         50502.15
# CHIAPAS                          51794.30
# CHIHUAHUA                        57012.00
# COAHUILA DE ZARAGOZA             60018.40
# COLIMA                           58342.70
# DISTRITO FEDERAL                 39240.41
# DURANGO                          55905.40
# GUANAJUATO                       62530.71
# GUERRERO                         57377.00
# HIDALGO                          48228.97
# JALISCO                          52232.97
# MEXICO                           42586.90
# MICHOACAN DE OCAMPO              56136.51
# MORELOS                          52017.16
# NAYARIT                          52208.20
# NUEVO LEON                       62665.00
# OAXACA                           53427.70
# PUEBLA                           45405.60
# QUERETARO                        61059.12
# QUINTANA ROO                     55713.46
# SAN LUIS POTOSI                  67898.10
# SINALOA                          48909.85
# SONORA                           58616.70
# TABASCO                          56587.06
# TAMAULIPAS                       60123.22
# TLAXCALA                         49852.16
# VERACRUZ DE IGNACIO DE LA LLAVE  66967.51
# YUCATAN                          54492.01
# ZACATECAS                        56225.90
